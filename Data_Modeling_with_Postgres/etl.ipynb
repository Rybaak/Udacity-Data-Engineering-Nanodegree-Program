# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data/')

# %%
filepath = song_files[0]
filepath2 = song_files[1]
print(filepath)
print(filepath2)
# Out:
# /home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json
# /home/workspace/data/song_data/A/B/C/TRABCTK128F934B224.json

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  AR8IEZO1187B99055E              NaN                               NaN
#
#     artist_name   duration  num_songs             song_id          title  year
# 0  Marc Shaiman  149.86404          1  SOINLJW12A8C13314C  City Slickers  2008

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[[df.columns[7], df.columns[8], df.columns[0], df.columns[9], df.columns[5]]]
song_data = song_data.drop_duplicates(keep='first')
song_data = song_data.values[0]
song_data
# Out:
# array(['SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008,
#        149.86404], dtype=object)

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id', 'artist_name', 'artist_location', 'artist_longitude', 'artist_latitude']].values[0]
artist_data = list(artist_data)
artist_data
# Out:
# ['AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data/')

# %%
filepath = log_files[0]
filepath2 = log_files[1]
print(filepath)
print(filepath2)
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-29-events.json
# /home/workspace/data/log_data/2018/11/2018-11-27-events.json

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
# 1         Gang Starr  Logged In     Layla      F             88  Griffin
# 2              3OH!3  Logged In     Layla      F             89  Griffin
# 3        RÃÂ¶yksopp  Logged In     Jacob      M             54    Klein
# 4         Kajagoogoo  Logged In     Layla      F             90  Griffin
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 1  151.92771  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 2  192.52200  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 3  369.81506  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  223.55546  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
#
#    registration  sessionId                                         song  \
# 0  1.540558e+12        954                            Ain't No Sunshine
# 1  1.541057e+12        984                   My Advice 2 You (Explicit)
# 2  1.541057e+12        984  My First Kiss (Feat. Ke$ha) [Album Version]
# 3  1.540558e+12        954                       The Girl and The Robot
# 4  1.541057e+12        984                                      Too Shy
#
#    status             ts                                          userAgent  \
# 0     200  1543449657796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543449690796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2     200  1543449841796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     200  1543449895796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543450033796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
#
#   userId
# 0     73
# 1     24
# 2     24
# 3     73
# 4     24

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df.query("page == 'NextSong'")
df.head()
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
# 1         Gang Starr  Logged In     Layla      F             88  Griffin
# 2              3OH!3  Logged In     Layla      F             89  Griffin
# 3        RÃÂ¶yksopp  Logged In     Jacob      M             54    Klein
# 4         Kajagoogoo  Logged In     Layla      F             90  Griffin
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 1  151.92771  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 2  192.52200  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
# 3  369.81506  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  223.55546  paid         Lake Havasu City-Kingman, AZ    PUT  NextSong
#
#    registration  sessionId                                         song  \
# 0  1.540558e+12        954                            Ain't No Sunshine
# 1  1.541057e+12        984                   My Advice 2 You (Explicit)
# 2  1.541057e+12        984  My First Kiss (Feat. Ke$ha) [Album Version]
# 3  1.540558e+12        954                       The Girl and The Robot
# 4  1.541057e+12        984                                      Too Shy
#
#    status             ts                                          userAgent  \
# 0     200  1543449657796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 1     200  1543449690796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2     200  1543449841796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     200  1543449895796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1543450033796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
#
#   userId
# 0     73
# 1     24
# 2     24
# 3     73
# 4     24

# %%
t = pd.to_datetime(df['ts'], unit='ms') 
t.head()
# Out:
# 0   2018-11-29 00:00:57.796
# 1   2018-11-29 00:01:30.796
# 2   2018-11-29 00:04:01.796
# 3   2018-11-29 00:04:55.796
# 4   2018-11-29 00:07:13.796
# Name: ts, dtype: datetime64[ns]

# %%
##print(t, t.dt.hour, t.dt.day, t.dt.week)
t_hour = t.dt.hour
t_day  = t.dt.day
t_week = t.dt.week
t_month = t.dt.month
t_year = t.dt.year
t_weekday = t.dt.weekday
time_data = (t, t_hour, t_day, t_week, t_month, t_year, t_weekday)
column_labels = ('start_time', 'hour', 'day', 'week', 'month', 'year','weekday')

# %%
time_df = pd.DataFrame(dict(zip(column_labels, time_data)))

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
user_df = user_df.drop_duplicates(keep='first')

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():
    #print(row)
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
        print('song ' + str(row.song), 'artist ' + str(row.artist), 'length ' + str(row.length))
        print(songid, artistid)
    # insert songplay record
    songplay_data = (index, pd.to_datetime(row.ts, unit='ms'), row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    #cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# song Ain't No Sunshine artist Sydney Youngblood length 238.07955
# None None
# song My Advice 2 You (Explicit) artist Gang Starr length 151.92771
# None None
# song My First Kiss (Feat. Ke$ha) [Album Version] artist 3OH!3 length 192.522
# None None
# song The Girl and The Robot artist RÃÂ¶yksopp length 369.81506
# None None
# song Too Shy artist Kajagoogoo length 223.55546
# None None
# song Potential artist The Jimmy Castor Bunch length 306.54649
# None None
# song The Great Satan (What Would Satan Do Mix) artist Ministry length 186.69669
# None None
# song The Screamer artist Bouncing Souls length 117.31546
# None None
# song Knife Going In (Album Version) artist Tegan And Sara length 129.67138
# None None
# song The Greatest View (Album Version) artist Silverchair length 242.96444
# None None
# song T.N.T. For The Brain (112 Bpm) (Radio Edit) artist Enigma length 242.78159
# None None
# song Mon MÃÂ©tro artist Anis length 278.12526
# None None
# song Fly Like An Eagle artist Seal length 254.06649
# None None
# song Restless artist UNKLE Feat. Josh Homme length 307.19955
# None None
# song You're The One artist Dwight Yoakam length 239.3073
# None None
# song Blue artist Elastica length 141.92281
# None None
# song Channel 10 artist Capone-N-Noreaga length 194.82077
# None None
# None None
# song So far so long artist Seine length 173.66159
# None None
# song What A Shame (Album Version) artist Shinedown length 258.97751
# None None
# song Vanity Case (nouvelle version) artist Iva length 205.322
# None None
# song Hammerhead (Explicit) artist Cathy Davey length 273.52771
# None None
# song Hekura artist Jorge Reyes Valencia length 127.81669
# None None
# song Candle artist Sonic Youth length 299.10159
# None None
# song Slow Dancing In A Burning Room artist John Mayer length 241.99791
# None None
# song Geek In The Pink (Album Version) artist Jason Mraz length 235.49342
# None None
# song Technologic artist Daft Punk length 283.19302
# None None
# song Again artist Flyleaf length 184.89424
# None None
# song Carol Brown artist Flight Of The Conchords length 206.8371
# None None
# song Invalid artist Tub Ring length 233.69098
# None None
# song Daylight artist Aesop Rock length 266.16118
# None None
# song Undercover Martyn artist Two Door Cinema Club length 168.09751
# None None
# song Clear Channel (Fuck Off!) artist Leftover Crack length 254.98077
# None None
# song They Might Follow You artist Tiny Vipers length 210.23302
# None None
# song The Climb artist Miley Cyrus length 236.85179
# None None
# song Who Can Compare artist Foolish Things length 266.86649
# None None
# song Somebody To Love artist Justin Bieber length 220.89098
# None None
# song Tiempo artist Jarabe De Palo length 283.14077
# None None
# song Happy Alone artist Kings Of Leon length 238.8371
# None None
# song I Smell A Rat (LP Version) artist Clarence Carter length 161.4624
# None None
# song Kryptonite (Radio Edit) (feat. Big Boi) artist Purple Ribbon All-Stars feat. Big Boi length 242.83383
# None None
# song Old Blue Jeans artist Hannah Montana length 202.03057
# None None
# song Replay artist Iyaz length 181.9424
# None None
# song Aquamosh artist Plastilina Mosh length 236.56444
# None None
# song Be (Intro) artist Common length 144.16934
# None None
# song I May Never Find artist Chris Brown length 275.1473
# None None
# song Runaway (Original) artist iio length 217.80853
# None None
# song Eric B. Is On The Cut artist Eric B. & Rakim length 224.23465
# None None
# song A Woman's Love   (LP Version) artist Carla Thomas length 174.62812
# None None
# song Falling in Hate artist Five Finger Death Punch length 180.32281
# None None
# song Desert Rose artist Sting length 285.93587
# None None
# song If I Cut My Hair_ Hawaii Will Sink (Album Version) artist Chiodos length 143.20281
# None None
# song I Wonder Why artist Dion & The Belmonts length 138.65751
# None None
# song Prayin For Help (Amended Album Version) artist T.I. length 261.98159
# None None
# song Sinister Kid artist The Black Keys length 224.49587
# None None
# song Flume artist Bon Iver length 218.98404
# None None
# song All The Right Moves artist OneRepublic length 237.97506
# None None
# song Word Up artist Cameo length 263.52281
# None None
# song Auditorium artist Mos Def / Slick Rick length 274.442
# None None
# song Hallowed Be My Name artist HAMMERFALL length 236.01587
# None None
# song I Am The Club (Explicit Album Version) artist Plies length 223.65995
# None None
# song Hearts Break artist Slaid Cleaves length 198.76526
# None None
# song Sugar Ray (LP Version) artist Todd Barry length 126.82404
# None None
# song The Way I Loved You artist Taylor Swift length 245.36771
# None None
# song Inside My Love artist Minnie Riperton length 287.79057
# None None
# song Comet Course artist Flying Lotus length 181.52444
# None None
# song Can't Take My Eyes Off You artist Muse length 211.12118
# None None
# song Elsewhere artist Edenbridge length 137.69098
# None None
# song Hong Kong Blues artist Frank Ifield length 138.23955
# None None
# song You're The One artist Dwight Yoakam length 239.3073
# None None
# song Threat artist Jay-Z length 245.68118
# None None
# song The Gift artist Angels and Airwaves length 302.05342
# None None
# song Idle Hands (Album Version) artist Stone Sour length 236.77342
# None None
# song You're The One artist Dwight Yoakam length 239.3073
# None None
# song Wishing Well artist The Airborne Toxic Event length 237.13914
# None None
# song Here Without You artist 3 Doors Down length 237.13914
# None None
# song Dry Spell artist Hazmat Modine length 285.02159
# None None
# song Secrets artist OneRepublic length 224.67873
# None None
# song Fuck and Run artist Liz Phair length 187.34975
# None None
# song Far Away (Album Version) artist Nickelback length 238.18404
# None None
# song Girl I Love You artist Massive Attack length 326.60853
# None None
# song Beat Goes On [Featuring Kanye West] (Album Version) artist Madonna length 266.89261
# None None
# song Don't Walk Away artist Sick Puppies length 227.83955
# None None
# song Bone Machine artist Pixies length 184.2673
# None None
# song Mi Marfil artist Andres Calamaro length 65.88036
# None None
# song None Shall Pass (Main) artist Aesop Rock length 245.65506
# None None
# song With You artist The Subways length 182.17751
# None None
# song To Go Beyond (II) artist Enya length 179.90485
# None None
# song Glitter In The Air artist P!nk length 227.02975
# None None
# song Heartbeats artist JosÃÂ© Gonzalez length 158.48444
# None None
# song Better Is One Day (Stereo Trax) artist Passion length 405.10649
# None None
# song Two Shoes artist The Cat Empire length 316.65587
# None None
# song Someday artist Mariah Carey length 246.09914
# None None
# song Interactive Halloween Bear artist Restiform Bodies length 229.14567
# None None
# song Better Off Alone artist Alice Deejay length 216.5024
# None None
# song Next Evil artist Interpol length 200.202
# None None
# song OMG artist Usher featuring will.i.am length 395.72853
# None None
# song Fighters (feat. Matthew Santos) (Amended Album Version) artist Lupe Fiasco feat. Matthew Santos length 213.34159
# None None
# song La Guitarra artist Los AutÃÂ©nticos Decadentes length 218.48771
# None None
# song At Least It's Raining artist Brand New Disaster length 190.82404
# None None
# song Breaking Inside (Album Version) artist Shinedown length 229.43302
# None None
# song The Moon Asked The Crow artist Cocorosie length 232.17587
# None None
# song Pais E Filhos artist LegiÃÂ£o Urbana length 307.3824
# None None
# song Word Up! artist Cameo length 211.98322
# None None
# song Dreamer artist Atmosphere length 244.61016
# None None
# song Born Losers artist Matthew Good length 319.16363
# None None
# song January Wedding artist The Avett Brothers length 227.99628
# None None
# song I'm Sorry artist James Newton Howard length 141.5571
# None None
# song The Fear artist Lily Allen length 206.65424
# None None
# song Revelry artist Kings Of Leon length 201.79546
# None None
# song I Know You Got Soul artist Eric B. & Rakim length 281.86077
# None None
# song Hello artist Eminem length 248.2673
# None None
# song Stella The Artist artist David Gray length 217.33832
# None None
# song The Sweetest Taboo artist Sade length 278.46485
# None None
# song That's How You Like It artist BeyoncÃÂ© feat. Jay-Z length 219.19302
# None None
# song Hey Shorty (Yeah Yeah Pt. II) (Feat. U$O & Johnson) artist Kato length 195.47383
# None None
# song I'll Never Kill Again artist Wise Intelligent length 300.56444
# None None
# song Quiero Quererte Querer artist El Arrebato length 234.57914
# None None
# song Is This It artist The Strokes length 155.34975
# None None
# song I Get Money artist 50 Cent length 223.89506
# None None
# song (There Was A) Tall Oak Tree artist Dorsey Burnette length 125.85751
# None None
# song Horse With No Name artist America length 262.89587
# None None
# song VÃÂ­cio De Ti artist Mesa (Portuguese Group) length 246.33424
# None None
# song Solo Creo Lo Que Veo artist Alaska Y Dinarama length 231.44444
# None None
# song Sehnsucht artist Rammstein length 244.40118
# None None
# song Woman Like A Man artist Damien Rice length 284.29016
# None None
# song Sequencer Mood 1 artist Vittorio Lue length 33.802
# None None
# song Ooh artist Scissor Sisters length 209.34485
# None None
# song Overture artist The Coffee Club Orchestra length 386.76853
# None None
# song Save Tonight artist Eagle-Eye Cherry length 242.78159
# None None
# song Move On Up (Extended LP Version) artist Curtis Mayfield length 534.33424
# None None
# song Death Rides a Horse artist Russian Circles length 346.20036
# None None
# song Old Panda Days (w/ Nick Krgovich) artist Casiotone For The Painfully Alone length 139.41506
# None None
# song I CAN'T GET STARTED artist Ron Carter length 497.13587
# None None
# song No Remorse artist Metallica length 386.66404
# None None
# song Wot artist Captain Sensible length 338.72934
# None None
# song Blues (2005 Digital Remaster) artist Renato Carosone length 192.57424
# None None
# song Invalid artist Tub Ring length 233.69098
# None None
# song Harder Than You Know artist Escape The Fate length 259.39546
# None None
# song New Soul artist Yael NaÃÂ¯m length 214.85669
# None None
# song Weird Fishes/Arpeggi artist Radiohead length 317.93587
# None None
# song A Lack Of Color (Album Version) artist Death Cab for Cutie length 216.42404
# None None
# song Sooner Than You Think artist New Order length 313.62567
# None None
# song You're The One artist Dwight Yoakam length 239.3073
# None None
# song Love My Shake artist Fukkk Offf length 409.05098
# None None
# song Spit It Out [Explicit] artist Slipknot length 159.76444
# None None
# song Big Red artist Slaves To Gravity length 225.25342
# None None
# song Holy Roller Novocaine artist Kings Of Leon length 242.99057
# None None
# song Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) artist Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner length 277.15873
# None None
# song All My Friends artist Amos Lee length 259.26485
# None None
# song No Puedo Evitar (Pensar En Ti) artist Duncan Dhu length 202.91873
# None None
# song She Has A Girlfriend Now artist Reel Big Fish length 185.80853
# None None
# song Burning Creation artist Amon Amarth length 298.55302
# None None
# song Back To You artist John Mayer length 241.6322
# None None
# song Don't Turn Your Back On Fear artist The 69 Eyes length 224.78322
# None None
# song Ladybird artist Ladytron length 278.07302
# None None
# song Famous Blue Raincoat artist Leonard Cohen length 307.43465
# None None
# song Take It Easy (love Nothing) (Album Version) artist Bright Eyes length 200.72444
# None None
# song Live Forever [Fly With Me] [feat. Daryl Hall] artist Gym Class Heroes length 428.77342
# None None
# song Promise Me artist Beverley Craven length 219.34975
# None None
# song Ringing Bells artist Masta Killa length 195.70893
# None None
# song Droomland (duet met Paul de Leeuw) artist Andre Hazes length 206.70649
# None None
# song My Night With the Prostitute From Marseille artist Beirut length 185.15546
# None None
# song This Is Beautiful artist Tyrone Wells length 275.80036
# None None
# song Look What They Done To My Song_ Ma artist Melanie length 245.86404
# None None
# song The Middle artist Jimmy Eat World length 166.00771
# None None
# song Taja's Lude (Interlude) artist Blackstreet length 26.90567
# None None
# song Juramento artist Omara Portuondo length 202.86649
# None None
# song The News artist Jack Johnson length 146.25914
# None None
# song TÃÂº artist Shakira length 322.79465
# None None
# song Sebrina_ Paste And Plato artist Jellyfish length 143.17669
# None None
# song Bitter Sweet Symphony artist The Verve length 360.25424
# None None
# song Lissoms artist Toro Y Moi length 133.85098
# None None
# song Sample Track 2 artist Simon Harris length 195.83955
# None None
# song Figure.09 (Album Version) artist Linkin Park length 197.51138
# None None
# song The Wonderful Cross artist Michael W. Smith length 381.88363
# None None
# song Teardrop artist Underworld length 329.53424
# None None
# song This Afternoon (Album Version) artist Nickelback length 274.65098
# None None
# song O Canto Da Ema artist Jackson Do Pandeiro length 157.51791
# None None
# song Heartbreak Warfare artist John Mayer length 269.71383
# None None
# song Waterfall artist Triumvirat length 294.81751
# None None
# song TAVALLINEN TARINA artist Hausmylly length 207.75138
# None None
# song Step To Me artist Thousand Foot Krutch length 180.58404
# None None
# song Only Time (Original Version) artist Enya length 218.53995
# None None
# song Still be Friends artist Billie The Vision & The Dancers length 136.46322
# None None
# song Non Saprai Mai artist Claudio Minore length 282.01751
# None None
# song Fireflies artist Charttraxx Karaoke length 225.17506
# None None
# song The Worst Taste In Music (Extended) artist The Radio Dept. length 193.72363
# None None
# song War on war artist Wilco length 227.65669
# None None
# song Despre tine artist O-Zone length 226.16771
# None None
# song Whataya Want From Me artist Adam Lambert length 227.39546
# None None
# song Red artist Mission Of Burma length 218.20036
# None None
# song Damaged [Feat. Fabolous] artist Danity Kane length 247.74485
# None None
# song Sulk artist Radiohead length 223.00689
# None None
# song The English Way artist Fightstar length 212.61016
# None None
# song To Be With You artist Hoobastank length 242.78159
# None None
# song Poison Oak (Album Version) artist Bright Eyes length 279.87546
# None None
# song Grand Hotel artist Procol Harum length 368.56118
# None None
# song Planet Telex artist Radiohead length 259.29098
# None None
# song SinceritÃÂ© Et Jalousie artist Alliance Ethnik length 195.94404
# None None
# song New Born artist Muse length 365.45261
# None None
# song 5_ 6_ 7_ 8 artist Steps length 201.76934
# None None
# song The Heart Of Life artist John Mayer length 198.19057
# None None
# song Revelry artist Kings Of Leon length 201.79546
# None None
# song Draw The Line artist David Gray length 263.33995
# None None
# song The Ugly One (AKA Lee Van Cleef) artist King Stitt length 176.27383
# None None
# song Invalid artist Tub Ring length 233.69098
# None None
# song Cathar Rhythm artist Era length 200.56771
# None None
# song The Queen of Nothing artist + / - {Plus/Minus} length 318.98077
# None None
# song Good Time artist Crystal Castles length 175.51628
# None None
# song Figures artist The Whitest Boy Alive length 234.57914
# None None
# song Bone Broke artist The White Stripes length 194.48118
# None None
# song Are You The Walrus? artist Furthermore length 211.69587
# None None
# song Amityville artist Eminem / Bizarre length 244.55791
# None None
# song I'm Not Calling You A Liar artist Florence + The Machine length 185.3122
# None None
# song Signos artist Soda Stereo length 316.73424
# None None
# song You Belong With Me artist Taylor Swift length 230.47791
# None None
# song Rearviewmirror artist Pearl Jam length 283.89832
# None None
# song Me So Horny artist The 2 Live Crew length 188.31628
# None None
# song Loco artist 311 length 113.26649
# None None
# song Midnight Groovin' (7" Version) (2006 Digital Remaster) artist Light Of The World length 207.0722
# None None

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
